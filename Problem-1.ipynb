# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1D Random walk
#
# We will concider two kinds of 1D random talk.
# * $dx$ is uniformly distributed between $[-1/2, +1/2]$.
# * $dx=+1$ with probability 1/2 and $dx=-1$ with probability 1/2.
#
# For both kinds of the 1D random walk, you should do the following:
# * Plot a single trajectory.
# * Plot the histogram of the end point for an ensemble of trajectories.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

# %%
# define the function of step with 𝑑𝑥 distributed between  [−1/2,+1/2]
def One_dim(i_step):
    step_x = np.random.random(i_step)-1/2    
    return (np.cumsum(step_x))

# position and step number
i_step = 1
i_walk = 10000

x_f = np.zeros(i_walk)

for run in range(i_walk):
    x = One_dim(i_step)
    x_f[run] = x[-1]
    
pylab.plot(x_f,) 
pylab.show()

# %%
def stepdistribution(steps, n):
    site = np.zeros((n,))
    for i in range(n):
        P = np.random.random((steps,))
        P = P - 0.5
        final_position = np.sum(P)
        site[i] = final_position
    return site

site = total(1000, 1000)
plt.hist(site, bins=100)
plt.show()

# %%
import pylab
import random 

# position and step number
i = 10000

x = np.zeros(i) 

for n in range(1, i): 
    val = random.randint(1, 2) 
    if val == 1: 
        x[n] = x[n - 1] + 1
    elif val == 2: 
        x[n] = x[n - 1] - 1

pylab.plot(x) 
pylab.show()

# %%
def stepdistribution2(steps, n):
    site2 = np.zeros((n,))
    for i in range(n):
        P = np.random.randint(2, size=steps)
        Pb = prob * 0.5
        final_position = np.sum(P)
        site2[i] = final_position
    return site2
site = total(1000, 1000)
plt.hist(site, bins=100)
plt.show()
